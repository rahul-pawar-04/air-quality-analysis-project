# %%
import pandas as pd 
df = pd.read.csv(''air_quality_historical.csv'')
print(df.head())
# Out:
#   Cell In[1], line 2
#     df = pd.read.csv(''air_quality_historical.csv'')
#                        ^
# SyntaxError: invalid syntax. Is this intended to be part of the string?

# %%
import pandas as pd
df = pd.read.csv('air_quality_historical.csv')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read.csv('air_quality_historical.csv')
#       3 print(df.head())
#
# AttributeError: module 'pandas' has no attribute 'read'

# %%
import pandas as pd

df = pd.read_csv('air_quality_historical.csv')

print(df.head())
# Out:
#          date       pm10      pm2_5  carbon_monoxide  nitrogen_dioxide  \
# 0  2022-08-01        NaN        NaN              NaN               NaN
# 1  2022-08-02        NaN        NaN              NaN               NaN
# 2  2022-08-03        NaN        NaN              NaN               NaN
# 3  2022-08-04  42.084211  25.989474       407.578947         29.210526
# 4  2022-08-05  25.287500  16.737500       355.250000         27.179167
#
#    sulphur_dioxide      ozone  aerosol_optical_depth      dust  uv_index  \
# 0              NaN        NaN                    NaN       NaN       NaN
# 1              NaN        NaN                    NaN       NaN       NaN
# 2              NaN        NaN                    NaN       NaN       NaN
# 3        47.605263  60.684211               0.469474  7.105263  2.131579
# 4        39.725000  41.375000               0.298750  1.458333  1.041667
#
#       us_aqi  european_aqi
# 0        NaN           NaN
# 1        NaN           NaN
# ...

# %%
print(df.columns)
# Out:
# Index(['date', 'pm10', 'pm2_5', 'carbon_monoxide', 'nitrogen_dioxide',
#        'sulphur_dioxide', 'ozone', 'aerosol_optical_depth', 'dust', 'uv_index',
#        'us_aqi', 'european_aqi'],
#       dtype='str')

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1298 entries, 0 to 1297
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   1298 non-null   str
#  1   pm10                   1295 non-null   float64
#  2   pm2_5                  1295 non-null   float64
#  3   carbon_monoxide        1295 non-null   float64
#  4   nitrogen_dioxide       1295 non-null   float64
#  5   sulphur_dioxide        1295 non-null   float64
#  6   ozone                  1295 non-null   float64
#  7   aerosol_optical_depth  1295 non-null   float64
#  8   dust                   1295 non-null   float64
#  9   uv_index               1295 non-null   float64
#  10  us_aqi                 1294 non-null   float64
#  11  european_aqi           1294 non-null   float64
# dtypes: float64(11), str(1)
# memory usage: 121.8 KB
# None
# date                     0
# pm10                     3
# pm2_5                    3
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df['pm2_5'])
plt.title("PM2.5 Trend in Mumbai")
plt.xlabel("Days")
plt.ylabel("PM2.5")
plt.show()

# %%
print("Rows and Columns:", df.shape)
# Out:
# Rows and Columns: (1298, 12)

# %%
print(df.isnull().sum())
# Out:
# date                     0
# pm10                     3
# pm2_5                    3
# carbon_monoxide          3
# nitrogen_dioxide         3
# sulphur_dioxide          3
# ozone                    3
# aerosol_optical_depth    3
# dust                     3
# uv_index                 3
# us_aqi                   4
# european_aqi             4
# dtype: int64

# %%
print(df.describe())
# Out:
#               pm10        pm2_5  carbon_monoxide  nitrogen_dioxide  \
# count  1295.000000  1295.000000      1295.000000       1295.000000
# mean     65.910178    42.600793       472.714250         23.278415
# std      38.722150    29.778618       299.274358         19.617955
# min       1.058333     0.745833        59.125000          0.000000
# 25%      40.622917    20.718750       225.520833         10.812500
# 50%      55.000000    30.825000       425.833333         17.254167
# 75%      80.950000    58.395833       635.145833         27.210417
# max     403.337500   279.779167      2350.625000        116.245833
#
#        sulphur_dioxide        ozone  aerosol_optical_depth         dust  \
# count      1295.000000  1295.000000            1295.000000  1295.000000
# mean         31.541787   100.898694               0.502323    19.148054
# std          28.034848    46.094902               0.233945    23.569055
# min           0.241667    26.416667               0.039167     0.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,5))
plt.plot(df['pm10'])
plt.title("PM10 Trend in  Mumbai")
plt.xlabel("days")
plt.ylabel("PM10")
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])

monthly_pm25 = df.groupby(df['date'].dt.month)['pm2_5'].mean()

print(monthly_pm25)
# Out:
# date
# 1     65.812769
# 2     61.036408
# 3     51.516711
# 4     34.497500
# 5     24.483781
# 6     20.347407
# 7     20.551478
# 8     19.041270
# 9     20.890660
# 10    44.357157
# 11    69.958333
# 12    65.314180
# Name: pm2_5, dtype: float64

# %%
print("highest pm2.5:", df['pm2_5'].max())
print("lowest pm3.5:", df['pm2_5'].min())
print("averagebpm2.5:", df['pm2_5'].mean())
# Out:
# highest pm2.5: 279.77916666666664
# lowest pm3.5: 0.7458333333333332
# averagebpm2.5: 42.60079302987197

# %%
correlation = df.corr(numeric_only=True)
print(correlation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 correlation = df.corr(numeric_only=True)
#       2 print(correlation)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("air_quality_historical.csv")

correlation = df.corr(numeric_only=True)

print(correlation)
# Out:
#                            pm10     pm2_5  carbon_monoxide  nitrogen_dioxide  \
# pm10                   1.000000  0.924611         0.813555          0.765249
# pm2_5                  0.924611  1.000000         0.912981          0.805170
# carbon_monoxide        0.813555  0.912981         1.000000          0.859668
# nitrogen_dioxide       0.765249  0.805170         0.859668          1.000000
# sulphur_dioxide        0.775582  0.800432         0.858880          0.927909
# ozone                  0.569923  0.669419         0.657143          0.383485
# aerosol_optical_depth  0.376739  0.363059         0.193866          0.105221
# dust                  -0.134915 -0.401504        -0.476223         -0.406539
# uv_index              -0.208685 -0.306763        -0.230563         -0.163575
# us_aqi                 0.764900  0.879604         0.852884          0.679294
# european_aqi           0.879236  0.934066         0.868597          0.751989
#
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

correlation = df.corr(numeric_only=True)

plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Air Quality Correlation Heatmap")
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])

plt.figure(figsize=(12,6))
plt.plot(df['date'], df['pm2_5'])
plt.title("PM2.5 Trend Over Time")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.show()

# %%
def aqi_category(pm25):
    if pm25 <= 12:
        return "Good"
    elif pm25 <= 35:
        return "Moderate"
    elif pm25 <= 55:
        return "Unhealthy for Sensitive Groups"
    elif pm25 <= 150:
        return "Unhealthy"
    elif pm25 <= 250:
        return "Very Unhealthy"
    else:
        return "Hazardous"

df['AQI_Category'] = df['pm2_5'].apply(aqi_category)

print(df['AQI_Category'].value_counts())
# Out:
# AQI_Category
# Moderate                          697
# Unhealthy                         357
# Unhealthy for Sensitive Groups    220
# Good                               11
# Very Unhealthy                      9
# Hazardous                           4
# Name: count, dtype: int64

# %%
df['AQI_Category'].value_counts().plot(
    kind='bar',
    figsize=(8,5),
    title='AQI Category Distribution'
)

plt.xlabel("AQI Category")
plt.ylabel("Number of Days")
plt.show()

# %%
df.to_csv("air_quality_dashboard.csv" , index=False)

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\rahul\OneDrive\Desktop\Air Quality Project

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'air_quality_dashboard.csv', 'air_quality_historical.csv', 'Untitled.ipynb', 'Untitled1.ipynb']
